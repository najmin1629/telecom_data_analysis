# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("telecom.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...   \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.head(1)
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
#
#       PaymentMethod MonthlyCharges  TotalCharges Churn
# 0  Electronic check          29.85         29.85    No
#
# [1 rows x 21 columns]

# %%
df[2:5]
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 2          No          No              No  Month-to-month              Yes
# 3         Yes          No              No        One year               No
# 4          No          No              No  Month-to-month              Yes
#
# ...

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df['customerID']
# Out:
# 0       7590-VHVEG
# 1       5575-GNVDE
# 2       3668-QPYBK
# 3       7795-CFOCW
# 4       9237-HQITU
# 5       9305-CDSKC
# 6       1452-KIOVK
# 7       6713-OKOMC
# 8       7892-POOKP
# 9       6388-TABGU
# 10      9763-GRSKD
# 11      7469-LKBCI
# 12      8091-TTVAX
# 13      0280-XJGEX
# 14      5129-JLPIS
# 15      3655-SNQYZ
# 16      8191-XWSZG
# 17      9959-WOFKT
# 18      4190-MFLUW
# 19      4183-MYFRB
# 20      8779-QRDMV
# 21      1680-VDCWW
# 22      1066-JKSGK
# 23      3638-WEABW
# 24      6322-HRPFA
# 25      6865-JZNKO
# 26      6467-CHFZW
# 27      8665-UTDHZ
# 28      5248-YGIJN
# 29      8773-HHUOZ
#            ...
# 7013    1685-BQULA
# 7014    9053-EJUNL
# 7015    0666-UXTJO
# 7016    1471-GIQKQ
# 7017    4807-IZYOZ
# 7018    1122-JWTJW
# 7019    9710-NJERN
# 7020    9837-FWLCH
# 7021    1699-HPSBG
# 7022    7203-OYKCT
# 7023    1035-IPQPU
# 7024    7398-LXGYX
# 7025    2823-LKABH
# 7026    8775-CEBBJ
# 7027    0550-DCXLH
# 7028    9281-CEDRU
# ...

# %%
df[['customerID','tenure']]
# Out:
#       customerID  tenure
# 0     7590-VHVEG       1
# 1     5575-GNVDE      34
# 2     3668-QPYBK       2
# 3     7795-CFOCW      45
# 4     9237-HQITU       2
# 5     9305-CDSKC       8
# 6     1452-KIOVK      22
# 7     6713-OKOMC      10
# 8     7892-POOKP      28
# 9     6388-TABGU      62
# 10    9763-GRSKD      13
# 11    7469-LKBCI      16
# 12    8091-TTVAX      58
# 13    0280-XJGEX      49
# 14    5129-JLPIS      25
# 15    3655-SNQYZ      69
# 16    8191-XWSZG      52
# 17    9959-WOFKT      71
# 18    4190-MFLUW      10
# 19    4183-MYFRB      21
# 20    8779-QRDMV       1
# 21    1680-VDCWW      12
# 22    1066-JKSGK       1
# 23    3638-WEABW      58
# 24    6322-HRPFA      49
# 25    6865-JZNKO      30
# 26    6467-CHFZW      47
# 27    8665-UTDHZ       1
# 28    5248-YGIJN      72
# 29    8773-HHUOZ      17
# ...          ...     ...
# 7013  1685-BQULA      40
# 7014  9053-EJUNL      41
# 7015  0666-UXTJO      34
# 7016  1471-GIQKQ       1
# 7017  4807-IZYOZ      51
# ...

# %%
df['tenure'].max()
# Out:
# 72

# %%
df[df.tenure>=32]
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 1     5575-GNVDE    Male              0      No         No      34
# 3     7795-CFOCW    Male              0      No         No      45
# 9     6388-TABGU    Male              0      No        Yes      62
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 16    8191-XWSZG  Female              0      No         No      52
# 17    9959-WOFKT    Male              0      No        Yes      71
# 23    3638-WEABW  Female              0     Yes         No      58
# 24    6322-HRPFA    Male              0     Yes        Yes      49
# 26    6467-CHFZW    Male              0     Yes        Yes      47
# 28    5248-YGIJN    Male              0     Yes         No      72
# 30    3841-NFECX  Female              1     Yes         No      71
# ...

# %%
df=pd.read_csv("telecom.csv",nrows=3)

# %%
df
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...   DeviceProtection  \
# 0  No phone service             DSL             No  ...                 No
# 1                No             DSL            Yes  ...                Yes
# 2                No             DSL            Yes  ...                 No
#
#   TechSupport StreamingTV StreamingMovies        Contract PaperlessBilling  \
# 0          No          No              No  Month-to-month              Yes
# 1          No          No              No        One year               No
# 2          No          No              No  Month-to-month              Yes
#
# ...

# %%
df=pd.read_csv("telecom.csv",header=None)

# %%
df
# Out:
#               0       1              2        3           4       5   \
# 0     customerID  gender  SeniorCitizen  Partner  Dependents  tenure
# 1     7590-VHVEG  Female              0      Yes          No       1
# 2     5575-GNVDE    Male              0       No          No      34
# 3     3668-QPYBK    Male              0       No          No       2
# 4     7795-CFOCW    Male              0       No          No      45
# 5     9237-HQITU  Female              0       No          No       2
# 6     9305-CDSKC  Female              0       No          No       8
# 7     1452-KIOVK    Male              0       No         Yes      22
# 8     6713-OKOMC  Female              0       No          No      10
# 9     7892-POOKP  Female              0      Yes          No      28
# 10    6388-TABGU    Male              0       No         Yes      62
# 11    9763-GRSKD    Male              0      Yes         Yes      13
# 12    7469-LKBCI    Male              0       No          No      16
# ...

# %%
df=pd.read_csv("telecom.csv")
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
new_df=df.fillna(method="ffill")

# %%
new_df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
new_df=df.fillna(method="bfill",axis="columns")

# %%
new_df
# Out:
#       customerID  gender SeniorCitizen Partner Dependents tenure PhoneService  \
# 0     7590-VHVEG  Female             0     Yes         No      1           No
# 1     5575-GNVDE    Male             0      No         No     34          Yes
# 2     3668-QPYBK    Male             0      No         No      2          Yes
# 3     7795-CFOCW    Male             0      No         No     45           No
# 4     9237-HQITU  Female             0      No         No      2          Yes
# 5     9305-CDSKC  Female             0      No         No      8          Yes
# 6     1452-KIOVK    Male             0      No        Yes     22          Yes
# 7     6713-OKOMC  Female             0      No         No     10           No
# 8     7892-POOKP  Female             0     Yes         No     28          Yes
# 9     6388-TABGU    Male             0      No        Yes     62          Yes
# 10    9763-GRSKD    Male             0     Yes        Yes     13          Yes
# ...

# %%
new_df=df.interpolate()
new_df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
new_df=df.dropna()
new_df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
new_df=df.replace({
    'No phone service':'Phone service not available',
    'No internet service':'Internet service not available'
})
new_df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# ...

# %%
g=df.groupby('gender')
g

# %%
for gender,gender_df in g:
    print(gender)
    print(gender_df)
# Out:
# Female
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 16    8191-XWSZG  Female              0      No         No      52
# 18    4190-MFLUW  Female              0     Yes        Yes      10
# 19    4183-MYFRB  Female              0      No         No      21
# 23    3638-WEABW  Female              0     Yes         No      58
# 25    6865-JZNKO  Female              0      No         No      30
# 29    8773-HHUOZ  Female              0      No        Yes      17
# 30    3841-NFECX  Female              1     Yes         No      71
# ...

# %%
g.max()
# Out:
#         customerID  SeniorCitizen Partner Dependents  tenure PhoneService  \
# gender
# Female  9987-LUTYD              1     Yes        Yes      72          Yes
# Male    9995-HOTOH              1     Yes        Yes      72          Yes
#
#        MultipleLines InternetService OnlineSecurity OnlineBackup  \
# gender
# Female           Yes              No            Yes          Yes
# Male             Yes              No            Yes          Yes
#
#        DeviceProtection TechSupport StreamingTV StreamingMovies  Contract  \
# gender
# Female              Yes         Yes         Yes             Yes  Two year
# Male                Yes         Yes         Yes             Yes  Two year
#
#        PaperlessBilling PaymentMethod  MonthlyCharges TotalCharges Churn
# gender
# Female              Yes  Mailed check          118.75        999.9   Yes
# Male                Yes  Mailed check          118.35        999.8   Yes

# %%
g.mean()
# Out:
#         SeniorCitizen     tenure  MonthlyCharges
# gender
# Female       0.162844  32.244553       65.204243
# Male         0.161463  32.495359       64.327482

# %%
g.describe()
# Out:
#        MonthlyCharges                                                      \
#                 count       mean        std    min     25%    50%     75%
# gender
# Female         3488.0  65.204243  30.061341  18.40  35.900  70.65  89.850
# Male           3555.0  64.327482  30.116093  18.25  35.225  70.10  89.875
#
#                SeniorCitizen            ...             tenure             \
#            max         count      mean  ...   75%  max   count       mean
# gender                                  ...
# Female  118.75        3488.0  0.162844  ...   0.0  1.0  3488.0  32.244553
# Male    118.35        3555.0  0.161463  ...   0.0  1.0  3555.0  32.495359
#
#
#               std  min  25%   50%   75%   max
# gender
# Female  24.463233  0.0  9.0  29.0  55.0  72.0
# Male    24.656359  0.0  9.0  29.0  56.0  72.0
#
# [2 rows x 24 columns]

# %%
# %matplotlib inline
g.plot()
# Out:
# gender
# Female    AxesSubplot(0.125,0.125;0.775x0.755)
# Male      AxesSubplot(0.125,0.125;0.775x0.755)
# dtype: object

# %%
prev_values=pd.DataFrame({
    "customerID":["7590-VHVEG","5575-GNVDE"],
    "gender":["Female","Male"],
    "tenure":[1,34]
})
prev_values
# Out:
#    customerID  gender  tenure
# 0  7590-VHVEG  Female       1
# 1  5575-GNVDE    Male      34

# %%
curr_values=pd.DataFrame({
    "customerID":["Rohit","Ankita"],
    "gender":["Male","Female"],
    "tenure":[25,50]
})
curr_values
# Out:
#   customerID  gender  tenure
# 0      Rohit    Male      25
# 1     Ankita  Female      50

# %%
df1=pd.concat([prev_values,curr_values],ignore_index=True)
df1
# Out:
#    customerID  gender  tenure
# 0  7590-VHVEG  Female       1
# 1  5575-GNVDE    Male      34
# 2       Rohit    Male      25
# 3      Ankita  Female      50

# %%
df1=pd.concat([prev_values,curr_values],keys=['prev','curr'])
df1
# Out:
#         customerID  gender  tenure
# prev 0  7590-VHVEG  Female       1
#      1  5575-GNVDE    Male      34
# curr 0       Rohit    Male      25
#      1      Ankita  Female      50

# %%
df1.loc["curr"]
# Out:
#   customerID  gender  tenure
# 0      Rohit    Male      25
# 1     Ankita  Female      50

# %%
df=pd.read_csv("telecom.csv")

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ...  DeviceProtection  \
# 0  No phone service             DSL             No  ...                No
# 1                No             DSL            Yes  ...               Yes
# 2                No             DSL            Yes  ...                No
# 3  No phone service             DSL            Yes  ...               Yes
# 4                No     Fiber optic             No  ...                No
#
# ...

# %%
df2=pd.DataFrame({
    "customerID":["7590-VHVEG","5575-GNVDE"],
    "gender":["Female","Male"]
})
df2
# Out:
#    customerID  gender
# 0  7590-VHVEG  Female
# 1  5575-GNVDE    Male

# %%
df3=pd.DataFrame({
    "customerID":["7590-VHVEG","5575-GNVDE"],
    "tenure":[1,34]
})
df3
# Out:
#    customerID  tenure
# 0  7590-VHVEG       1
# 1  5575-GNVDE      34

# %%
df4=pd.merge(df2,df3,on="customerID",indicator=True)
df4
# Out:
#    customerID  gender  tenure _merge
# 0  7590-VHVEG  Female       1   both
# 1  5575-GNVDE    Male      34   both

# %%
df5=df.pivot(index="tenure",columns="customerID")
df5
# Out:
#                gender                                                         \
# customerID 0002-ORFBO 0003-MKNFE 0004-TLHLJ 0011-IGKFF 0013-EXCHZ 0013-MHZWF
# tenure
# 0                 NaN        NaN        NaN        NaN        NaN        NaN
# 1                 NaN        NaN        NaN        NaN        NaN        NaN
# 2                 NaN        NaN        NaN        NaN        NaN        NaN
# 3                 NaN        NaN        NaN        NaN     Female        NaN
# 4                 NaN        NaN       Male        NaN        NaN        NaN
# 5                 NaN        NaN        NaN        NaN        NaN        NaN
# 6                 NaN        NaN        NaN        NaN        NaN        NaN
# 7                 NaN        NaN        NaN        NaN        NaN        NaN
# 8                 NaN        NaN        NaN        NaN        NaN        NaN
# 9              Female       Male        NaN        NaN        NaN     Female
# ...

# %%
df6=pd.melt(df,id_vars=["customerID"])
df6
# Out:
#         customerID variable   value
# 0       7590-VHVEG   gender  Female
# 1       5575-GNVDE   gender    Male
# 2       3668-QPYBK   gender    Male
# 3       7795-CFOCW   gender    Male
# 4       9237-HQITU   gender  Female
# 5       9305-CDSKC   gender  Female
# 6       1452-KIOVK   gender    Male
# 7       6713-OKOMC   gender  Female
# 8       7892-POOKP   gender  Female
# 9       6388-TABGU   gender    Male
# 10      9763-GRSKD   gender    Male
# 11      7469-LKBCI   gender    Male
# 12      8091-TTVAX   gender    Male
# 13      0280-XJGEX   gender    Male
# 14      5129-JLPIS   gender    Male
# 15      3655-SNQYZ   gender  Female
# 16      8191-XWSZG   gender  Female
# 17      9959-WOFKT   gender    Male
# 18      4190-MFLUW   gender  Female
# 19      4183-MYFRB   gender  Female
# 20      8779-QRDMV   gender    Male
# 21      1680-VDCWW   gender    Male
# 22      1066-JKSGK   gender    Male
# 23      3638-WEABW   gender  Female
# 24      6322-HRPFA   gender    Male
# ...
